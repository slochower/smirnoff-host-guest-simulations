# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
diagonal = np.loadtxt('/home/dslochower/data/projects/smirnoff-host-guest-simulations/diagonal.txt')
u_kln = np.loadtxt('/home/dslochower/data/projects/smirnoff-host-guest-simulations/u_kln.txt')

# %%
plt.figure()
plt.imshow(u_kln)
plt.colorbar()

# %%
np.shape(u_kln)
# Out:
# (46, 46)

# %%
u_kln
# Out:
# array([[  9.40417392e-01,   3.97862144e+00,   9.71731624e+00, ...,
#           2.57012634e+03,   2.68928565e+03,   2.81114544e+03],
#        [  4.41499766e-01,   1.32743938e+00,   4.91386975e+00, ...,
#           2.47708005e+03,   2.59408709e+03,   2.71379463e+03],
#        [  1.66867112e+00,   4.02337191e-01,   1.83649401e+00, ...,
#           2.38575946e+03,   2.50061423e+03,   2.61816949e+03],
#        ...,
#        [  2.50020579e+03,   2.38536301e+03,   2.27322073e+03, ...,
#           5.09690006e-01,   1.78801919e+00,   5.76683912e+00],
#        [  2.61840995e+03,   2.50085151e+03,   2.38599357e+03, ...,
#           1.94048769e+00,   5.03157285e-01,   1.76631763e+00],
#        [  2.73422657e+03,   2.61406585e+03,   2.49660563e+03, ...,
#           5.85903677e+00,   1.81942564e+00,   4.80305262e-01]])

# %%
u_kln_niel = np.loadtxt('/home/dslochower/data/projects/smirnoff-host-guest-simulations/u_kln_niel.txt')

# %%
plt.figure()
plt.imshow(u_kln_niel)
plt.colorbar()

# %%
plt.figure()
plt.imshow(u_kln - u_kln_niel)
plt.title('Dave `u_kln` - Niel `u_kln`')
plt.colorbar()
