# %%
library(cowplot)
library(ggplot2)
library(dplyr)
library(ggrepel)
library(devtools)

# %%
options(unzip = "internal")
devtools::install_github("wilkelab/cowplot")

# %%
# width = 6
# height = 6 * 1.2
# options(repr.plot.width=width, repr.plot.height=height)


dihedrals = 
  readr::read_csv("dihedrals.csv")
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   X1 = col_integer(),
#   atom1 = col_character(),
#   atom2 = col_character(),
#   atom3 = col_character(),
#   atom4 = col_character(),
#   phase = col_double(),
#   per = col_integer(),
#   phi_x = col_double(),
#   phi_y = col_double()
# )

# %%
ggplot(dihedrals, aes(x = phi_x, y = phi_y, label = paste0(atom1, "-", atom2))) + 
geom_point(size = 2.5) +
geom_abline(slope = 1, size = 0.1) +
coord_equal() + 
labs(subtitle="", 
   y="GAFF v1.7 dihedral force constant", 
   x=expression("SMIRNOFF99Frosst dihedral force constant (kcal/mol/"~rad^2~")"), 
   title="", 
   caption = "") +
background_grid(major = "xy", minor = "xy")
# Out:
# plot without title

# %%
distinct(dihedrals, phi_x, .keep_all=TRUE) %>%
ggplot(aes(x = phi_x, y = phi_y, label = paste0(atom1, "-", atom2))) + 
geom_point() +
geom_text_repel() +
geom_abline(slope = 1, size = 0.1) +
coord_equal() + 
labs(subtitle="", 
   y="GAFF v1.7 dihedral force constant", 
   x=expression("SMIRNOFF99Frosst dihedral force constant (kcal/mol/"~rad^2~")"), 
   title="", 
   caption = "")
# Out:
# plot without title

# %%
dihedrals$difference = dihedrals$phi_x - dihedrals$phi_y

# %%
ggplot(dihedrals, aes(x = phi_x, y = phi_y, label = paste0(atom1, "-", atom2))) + 
geom_point() +
geom_text_repel() +
geom_abline(slope = 1, size = 0.1) +
coord_equal() + 
labs(subtitle="", 
   y="GAFF v1.7 dihedral force constant", 
   x=expression("SMIRNOFF99Frosst dihedral force constant (kcal/mol/"~rad^2~")"), 
   title="", 
   caption = "")
# Out:
# plot without title

# %%
dat2 <- subset(dihedrals)

# %%
dat2$text <- ""

# %%
dat2$text[abs(dihedrals$difference) > 0.01] <- paste0(dihedrals$atom1[abs(dihedrals$difference) > 0.1], "-",
                                                     dihedrals$atom2[abs(dihedrals$difference) > 0.1], "-",
                                                     dihedrals$atom3[abs(dihedrals$difference) > 0.1], "-",
                                                     dihedrals$atom4[abs(dihedrals$difference) > 0.1])

# %%
ggplot(dat2, aes(x = phi_x, y = phi_y, label = text)) + 
geom_point(size=2, color = ifelse(dat2$text == "", "black", "red")) +
geom_label_repel(force=2, box.padding=1, 
                 segment.color = "grey50", 
                 segment.size = 0.2, 
                 fill="white",
                label.size = NA) +
geom_abline(slope = 1, size = 0.1) +
coord_equal() + 
labs(subtitle="", 
   y=expression("GAFF v1.7 dihedral "*phi*" (kcal/mol/"*rad^2*")"), 
   x=expression("SMIRNOFF99Frosst dihedral "*phi*" (kcal/mol/"*rad^2*")"),
   title="", 
   caption = "") +
theme_bw(14)
# Out:
# plot without title

# %%
missing = 
  readr::read_csv("missing-dihedrals.csv")
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   X1 = col_integer(),
#   atom1 = col_character(),
#   atom2 = col_character(),
#   atom3 = col_character(),
#   atom4 = col_character(),
#   phase = col_double(),
#   per = col_integer(),
#   phi_x = col_double(),
#   phi_y = col_character(),
#   `_merge` = col_character()
# )

# %%
missing
# Out:
#   X1 atom1 atom2 atom3 atom4 phase per phi_x phi_y _merge
# 1  3 O5    C1    C2    O2      0   3   0.144 NA    left_only
# 2  4 O5    C1    C2    O2      0   2   1.175 NA    left_only
# 3  5 O5    C1    C2    C3      0   3   0.156 NA    left_only
# 4 41 N1    C1    C2    C3    180   2   0.250 NA    left_only
# 5 42 N1    C1    C2    C3    180   1   0.200 NA    left_only
# 6 72 O5    C1    C2    H2      0   3   0.000 NA    left_only
# 7 73 O5    C1    C2    H2      0   1   0.250 NA    left_only
# 8 75 H1    C1    C2    O2      0   1   0.250 NA    left_only

# %%
ggplot(missing, aes(x = phi_x, y = 0, label = paste0(atom1, "-", atom2, "-", atom3, "-", atom4))) + 
geom_point(size=2) +
geom_abline(slope = 1, size = 0.1) +
coord_equal() + 
xlim(0, 1.2) +
ylim(0, 1.2) +
geom_label_repel(force=2, box.padding=1, 
                 segment.color = "grey50", 
                 segment.size = 0.2, 
                 fill="white",
                label.size = NA) +
labs(subtitle="", 
   y=expression("GAFF v1.7 dihedral "*phi*" (kcal/mol/"*rad^2*")"), 
   x=expression("SMIRNOFF99Frosst dihedral "*phi*" (kcal/mol/"*rad^2*")"),
   title="", 
   caption = "")
# Out:
# plot without title

# %%
theme_dviz_grid <- function(font_size = 14, font_family = "Arial", line_size = .5,
                            rel_small = 12/14, rel_tiny = 11/14, rel_large = 16/14,
                            colour = "grey90") {
  half_line <- font_size / 2
  
  cowplot::theme_cowplot(font_size = font_size, font_family = font_family, line_size = line_size,
                              rel_small = rel_small, rel_tiny = rel_tiny, rel_large = rel_large,
                              colour = colour)  %+replace%
    theme(
      plot.margin = margin(half_line/2, 0, half_line/2, 0),
      complete = TRUE
    )
}

# %%
ggplot(missing, aes(x = phi_x, y = 0, label = paste0(atom1, "-", atom2, "-", atom3, "-", atom4))) + 
geom_point(size=2) +
geom_abline(slope = 1, size = 0.1) +
coord_equal() + 
xlim(0, 1.2) +
ylim(0, 1.2) +
geom_label_repel(force=2, box.padding=1, 
                 segment.color = "grey50", 
                 segment.size = 0.2, 
                 fill="white",
                label.size = NA) +
labs(subtitle="", 
   y=expression("GAFF v1.7 dihedral "*phi*" (kcal/mol/"*rad^2*")"), 
   x=expression("SMIRNOFF99Frosst dihedral "*phi*" (kcal/mol/"*rad^2*")"),
   title="", 
   caption = "")
# Out:
# Warning message in get(Info[i, 1], envir = env):
# “internal error -3 in R_decompress1”

# %%
devtools::session_info()
# Out:
# Session info ------------------------------------------------------------------
# Packages ----------------------------------------------------------------------
#  setting  value
#  version  R version 3.3.2 (2016-10-31)
#  system   x86_64, linux-gnu
#  ui       X11
#  language (EN)
#  collate  en_US.UTF-8
#  tz       America/Los_Angeles
#  date     2018-09-19
#
#  package    * version date       source
#  assertthat   0.2.0   2017-04-11 CRAN (R 3.3.2)
#  base       * 3.3.2   2017-04-27 local
#  base64enc    0.1-3   2015-07-28 CRAN (R 3.3.2)
#  colorspace   1.3-2   2016-12-14 CRAN (R 3.3.2)
#  cowplot    * 0.7.0   2016-10-28 CRAN (R 3.3.2)
#  crayon       1.3.4   2017-09-16 CRAN (R 3.3.2)
#  datasets   * 3.3.2   2017-04-27 local
#  DBI          0.8     2018-03-02 CRAN (R 3.3.2)
#  devtools     1.13.6  2018-06-27 CRAN (R 3.3.2)
#  digest       0.6.15  2018-01-28 CRAN (R 3.3.2)
#  dplyr      * 0.5.0   2016-06-24 CRAN (R 3.3.2)
#  evaluate     0.10.1  2017-06-24 CRAN (R 3.3.2)
#  ggplot2    * 2.2.0   2016-11-11 CRAN (R 3.3.2)
#  ggrepel    * 0.8.0   2018-05-09 CRAN (R 3.3.2)
#  graphics   * 3.3.2   2017-04-27 local
#  grDevices  * 3.3.2   2017-04-27 local
#  grid         3.3.2   2017-04-27 local
#  gtable       0.2.0   2016-02-26 CRAN (R 3.3.2)
#  htmltools    0.3.6   2017-04-28 CRAN (R 3.3.2)
#  IRdisplay    0.4.4   2017-02-18 local
#  IRkernel     0.7.1   2017-02-18 local
#  jsonlite     1.5     2017-06-01 CRAN (R 3.3.2)
#  labeling     0.3     2014-08-23 CRAN (R 3.3.2)
#  lazyeval     0.2.1   2017-10-29 CRAN (R 3.3.2)
#  magrittr     1.5     2014-11-22 CRAN (R 3.3.2)
#  memoise      1.1.0   2017-04-21 CRAN (R 3.3.2)
#  methods    * 3.3.2   2017-04-27 local
#  munsell      0.4.3   2016-02-13 CRAN (R 3.3.2)
#  pbdZMQ       0.3-2   2018-01-31 CRAN (R 3.3.2)
#  pillar       1.2.1   2018-02-27 CRAN (R 3.3.2)
#  plyr         1.8.4   2016-06-08 CRAN (R 3.3.2)
#  R6           2.2.2   2017-06-17 CRAN (R 3.3.2)
#  Rcpp         0.12.16 2018-03-13 CRAN (R 3.3.2)
#  readr        1.0.0   2016-08-03 CRAN (R 3.3.2)
#  repr         0.13    2018-04-15 local
#  rlang        0.2.0   2018-02-20 CRAN (R 3.3.2)
#  scales       0.5.0   2017-08-24 CRAN (R 3.3.2)
#  stats      * 3.3.2   2017-04-27 local
#  stringi      1.1.7   2018-03-12 CRAN (R 3.3.2)
#  stringr      1.3.0   2018-02-19 CRAN (R 3.3.2)
#  tibble       1.4.2   2018-01-22 CRAN (R 3.3.2)
#  tools        3.3.2   2017-04-27 local
#  utils      * 3.3.2   2017-04-27 local
#  uuid         0.1-2   2015-07-28 CRAN (R 3.3.2)
#  withr        2.1.2   2018-03-15 CRAN (R 3.3.2)
